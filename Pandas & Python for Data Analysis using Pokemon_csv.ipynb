# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pokemon.csv')

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %% [markdown]
# ## Basic filtering

# %% [markdown]
# 1.How many Pokemons exsit with an Attack value greater than 150?
#
# Doing a little bit of visual exploration, we can have a sense of the most "powerful" pokemons (defined by their "Attack" feature). A boxplot is a great way to visualize this.

# %%
sns.boxplot(data = df,x = "attack")
# Out:
# <Axes: xlabel='attack'>

# %%
df.head(1)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 0             2.0            1.0  ...             88.1               1
#
#    sp_attack  sp_defense  speed  type1   type2  weight_kg  generation  \
# 0         65          65     45  grass  poison        6.9           1
#
#    is_legendary
# 0             0
#
# [1 rows x 41 columns]

# %%
df.loc[df['attack'] > 150].shape
# Out:
# (16, 41)

# %%
df.query('attack > 150')
# Out:
#                                      abilities  against_bug  against_dark  \
# 126  ['Hyper Cutter', 'Mold Breaker', 'Moxie']         1.00           1.0
# 129                    ['Intimidate', 'Moxie']         0.50           1.0
# 213                 ['Swarm', 'Guts', 'Moxie']         0.50           0.5
# 247                 ['Sand Stream', 'Unnerve']         2.00           0.5
# 256                   ['Blaze', 'Speed Boost']         0.25           0.5
# 288                                 ['Truant']         1.00           1.0
# 353       ['Insomnia', 'Frisk', 'Cursed Body']         0.50           2.0
# 382                                ['Drought']         1.00           1.0
# 383                               ['Air Lock']         0.50           1.0
# 408            ['Mold Breaker', 'Sheer Force']         1.00           1.0
# 444                ['Sand Veil', 'Rough Skin']         1.00           1.0
# 474                 ['Steadfast', 'Justified']         1.00           1.0
# ...

# %% [markdown]
# 2. select all pokemons with a speed of 10 or less

# %%
sns.boxplot(data = df, x = 'speed')
# Out:
# <Axes: xlabel='speed'>

# %%
df.loc[df['speed'] <= 10]
# Out:
#                                          abilities  against_bug  against_dark  \
# 212             ['Sturdy', 'Gluttony', 'Contrary']          1.0           1.0
# 327  ['Hyper Cutter', 'Arena Trap', 'Sheer Force']          1.0           1.0
# 437             ['Sturdy', 'Rock Head', 'Rattled']          1.0           1.0
# 445            ['Pickup', 'Thick Fat', 'Gluttony']          1.0           1.0
# 596                                 ['Iron Barbs']          1.0           1.0
# 770                     ['Innards Out', 'Unaware']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 212             1.0               1.0            1.0            1.0
# 327             1.0               0.0            1.0            1.0
# 437             1.0               1.0            1.0            2.0
# 445             1.0               1.0            1.0            2.0
# 596             0.5               0.5            0.5            2.0
# ...

# %%
df.query('speed <=10')
# Out:
#                                          abilities  against_bug  against_dark  \
# 212             ['Sturdy', 'Gluttony', 'Contrary']          1.0           1.0
# 327  ['Hyper Cutter', 'Arena Trap', 'Sheer Force']          1.0           1.0
# 437             ['Sturdy', 'Rock Head', 'Rattled']          1.0           1.0
# 445            ['Pickup', 'Thick Fat', 'Gluttony']          1.0           1.0
# 596                                 ['Iron Barbs']          1.0           1.0
# 770                     ['Innards Out', 'Unaware']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 212             1.0               1.0            1.0            1.0
# 327             1.0               0.0            1.0            1.0
# 437             1.0               1.0            1.0            2.0
# 445             1.0               1.0            1.0            2.0
# 596             0.5               0.5            0.5            2.0
# ...

# %%
df['speed'] <=10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 796    False
# 797    False
# 798    False
# 799    False
# 800    False
# Name: speed, Length: 801, dtype: bool

# %%
(df['speed'] <=10).sum()
# Out:
# np.int64(6)

# %%
slow_pokemon = df.query('speed <=10')

# %% [markdown]
# 3. How many pokemons have of Sp. Def value of 25 or less?

# %%
(df['sp_defense'] <= 25).sum()
# Out:
# 17

# %%
df.loc[df['sp_defense'] <=25].shape
# Out:
# (17, 41)

# %%
df.loc[df['sp_defense'] <=25]
# Out:
#                                            abilities  against_bug  \
# 9                        ['Shield Dust', 'Run Away']          1.0
# 10                                     ['Shed Skin']          1.0
# 12                       ['Shield Dust', 'Run Away']          0.5
# 13                                     ['Shed Skin']          0.5
# 38     ['Cute Charm', 'Competitive', 'Friend Guard']          0.5
# 89         ['Shell Armor', 'Skill Link', 'Overcoat']          1.0
# 97    ['Hyper Cutter', 'Shell Armor', 'Sheer Force']          1.0
# 115                 ['Swift Swim', 'Sniper', 'Damp']          1.0
# 128                        ['Swift Swim', 'Rattled']          1.0
# 173    ['Cute Charm', 'Competitive', 'Friend Guard']          0.5
# 193              ['Damp', 'Water Absorb', 'Unaware']          1.0
# 265                                    ['Shed Skin']          1.0
# 267                                    ['Shed Skin']          1.0
# ...

# %% [markdown]
# 4. select all the legengary pokemons

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
df['is_legendary'].sum()
# Out:
# 70

# %%
(df['attack'] > 150).sum()
# Out:
# 16

# %%
df.loc[df['is_legendary']]
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 0   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 0   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 0   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 0   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 0   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ..                          ...          ...           ...             ...
# 1   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1   ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
#
#     against_electric  against_fairy  against_fight  against_fire  \
# ...

# %%
df['is_legendary'] = df['is_legendary'].astype(bool)

# %%
df.loc[~df['is_legendary']].shape
# Out:
# (731, 41)

# %%
legendary_df = df.loc[df['is_legendary']]
legendary_df.head()
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 143  ['Pressure', 'Snow Cloak']         0.50           1.0             1.0
# 144      ['Pressure', 'Static']         0.50           1.0             1.0
# 145  ['Pressure', 'Flame Body']         0.25           1.0             1.0
# 149     ['Pressure', 'Unnerve']         2.00           2.0             1.0
# 150             ['Synchronize']         2.00           2.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 143               2.0            1.0            1.0           2.0
# 144               1.0            1.0            0.5           1.0
# 145               2.0            0.5            0.5           0.5
# 149               1.0            1.0            0.5           1.0
# 150               1.0            1.0            0.5           1.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %% [markdown]
# 5. Find the outlier

# %% [markdown]
# Find the pokemon that is clearly an outlier interms of attack/defense

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.sort_values(by = ['sp_defense','sp_attack'],ascending=(False,True)).head()
# Out:
#                               abilities  against_bug  against_dark  \
# 212  ['Sturdy', 'Gluttony', 'Contrary']         1.00           1.0
# 377          ['Clear Body', 'Ice Body']         1.00           1.0
# 381                         ['Drizzle']         1.00           1.0
# 248          ['Pressure', 'Multiscale']         1.00           2.0
# 249         ['Pressure', 'Regenerator']         0.25           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 212             1.0               1.0            1.0           1.00
# 377             1.0               1.0            1.0           2.00
# 381             1.0               2.0            1.0           1.00
# 248             1.0               2.0            1.0           0.25
# 249             1.0               2.0            0.5           0.50
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# 212           1.0             1.0            1.0  ...             50.0
# ...

# %% [markdown]
# Advanced selections

# %% [markdown]
# 6. How many fire-flying pokemons are there?

# %%
(df['type1'] =='against_fire').sum()
# Out:
# np.int64(0)

# %%
(df['type2'] =='against_flying').sum()
# Out:
# np.int64(0)

# %%
(
    (df['type1'] =='against_fire') & 
    (df['type2'] =='against_flying')
).sum()
# Out:
# np.int64(0)

# %%
df.loc[(
    (df['type1'] =='against_fire') & 
    (df['type2'] =='against_flying')
)]
# Out:
# Empty DataFrame
# Columns: [abilities, against_bug, against_dark, against_dragon, against_electric, against_fairy, against_fight, against_fire, against_flying, against_ghost, against_grass, against_ground, against_ice, against_normal, against_poison, against_psychic, against_rock, against_steel, against_water, attack, base_egg_steps, base_happiness, base_total, capture_rate, classfication, defense, experience_growth, height_m, hp, japanese_name, name, percentage_male, pokedex_number, sp_attack, sp_defense, speed, type1, type2, weight_kg, generation, is_legendary]
# Index: []
#
# [0 rows x 41 columns]

# %% [markdown]
# 7. How many 'Poison' pokemon are across both types?

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df['type1'].value_counts()
# Out:
# type1
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# dragon       27
# ghost        27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: count, dtype: int64

# %%
df['type2'].value_counts()
# Out:
# type2
# flying      95
# poison      34
# ground      34
# fairy       29
# psychic     29
# fighting    25
# steel       22
# dark        21
# grass       20
# water       17
# dragon      17
# ice         15
# ghost       14
# rock        14
# fire        13
# electric     9
# bug          5
# normal       4
# Name: count, dtype: int64

# %%
((df['type1'] == 'poison') | (df['type2'] == 'poison')).sum()
# Out:
# np.int64(64)

# %%
df.query("`type1` =='poison' or `type2` == 'poison'").shape
# Out:
# (64, 41)

# %% [markdown]
# & what pokemon of type1 has the strongest defense?

# %%
df.loc[df['type1'] == 'ice', 'sp_defense'].max()
# Out:
# 200

# %%
df.loc[
    (df['type1'] == 'ice') &
    (df['sp_defense'] == df.loc[df['type1'] == 'ice', 'sp_defense'].max())
]
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 377  ['Clear Body', 'Ice Body']          1.0           1.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 377               1.0            1.0            2.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 377             1.0            1.0  ...              NaN             378
#
#      sp_attack  sp_defense  speed  type1  type2  weight_kg  generation  \
# 377        100         200     50    ice    NaN      175.0           3
#
#      is_legendary
# 377             1
#
# [1 rows x 41 columns]

# %%
df.loc[df['type1'] == 'ice'].sort_values('sp_defense',ascending = False).head()
# Out:
#                                       abilities  against_bug  against_dark  \
# 377                  ['Clear Body', 'Ice Body']          1.0           1.0
# 614                                ['Levitate']          1.0           1.0
# 143                  ['Pressure', 'Snow Cloak']          0.5           1.0
# 470                  ['Snow Cloak', 'Ice Body']          1.0           1.0
# 583  ['Ice Body', 'Snow Warning', 'Weak Armor']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 377             1.0               1.0            1.0            2.0
# 614             1.0               1.0            1.0            2.0
# 143             1.0               2.0            1.0            1.0
# 470             1.0               1.0            1.0            2.0
# 583             1.0               1.0            1.0            2.0
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# ...
